# %% [markdown]
# # NLP basics

# %% [markdown]
# NLP modeling is no much difference from other ML models in its streamline: input-->model-->output. The devil is in details.  We will cover the difference in input, output, and model respectively.

# %% [markdown]
# ## NLP Input

# %% [markdown]
# The major difference in text input is: text are not numbers, thus computer can not understand. So the first step in NLP modeling is vectoring the text. This process is called 'text vectorization', or 'embedding'.Nothing mysteries, you just need to come up with a clever way to convert text into numbers. How are we going to do that?

# %%
import utils
utils.show_img('../NLP/img/vectorization.png', size_inch=18)

# %% [markdown]
# #### Simple Encoding
# The simplest way is to do one-hot encoding for each character/word. In English, you have 26 letters, and some special characters and symbols, and emoji of course. You can make a long vector whose length is the number of unique token. Then it's done! Simple, right?
#
# <font color='red'>Question:</font> What is the problem of this method? Can you come up with a better solution? (Hint: check Unicode, UTF8 systems)
#
# #### CV and TFIDF
# OK, this way is too naive, we don't want to do some this stupid thing sounds like encryption in World War II. Let's make it more complex. Let's use WORD instead of characters. To go even further, let's do counting. In this way, the most frequent words would have higher values. This method is called: Count Vectorization.
#
# <font color='red'>Question:</font> Write the code to to Count Vectorization. (intermediate: use package in sklearn. Hard: write the code from scratch.)
#
# <font color='red'>Question:</font> What is the problem with this method? How can you fix this?
#
# Some really clever guy came up with the solution of Term Frequency Invert Document Frequncy (TFIDF) method.
# <font color='red'>Question:</font> What is TF? What is IDF? Why TFIDF is superior than CV?
#
# <font color='red'>Assignment:</font> Write the code to do TFIDF vectorization. (intermediate: use package in sklearn. Hard: write the code from scratch.) What parameters can be tuned in TFIDF model? What is n-gram? Why n-gram is useful?
#
#
# Wow, if it is 1990 now, and you know TFIDF, you are very prepared to start a search company called Google or Baidu! You will be super rich today.

# %%
import utils
utils.show_img('../NLP/img/g_or_s.png', size_inch=18)

# %% [markdown]
# #### Word2Vec
# Or you could go to Stanford, sitting with Chris Manning and discuss: How can we improve the word vectorization even further?
#
# <font color='red'>Question:</font> What is word2vec? Why it is superior than TFIDF? How word2vec was trained? How the contextual information enter into the embedding?
#
# <font color='red'>Assignment:</font> Write the code to convert the text'Tom and Jerry are good friend? or not?'
#
# <font color='red'>Question:</font> List several embedding methods that appear at that time. (Hint: they are quite big name now! ) Write down how they are trained?
#
# You have gone a far way in embedding, let's take a break after anwering the following final questions:
#
# #### Model Based Embedding
# We will cover this in later part.
#
# #### Summary
# <font color='red'>Question:</font> Review the previous embedding methods, and list: How to embed a word? How to embed a sentence? How to embed a paragraph? How to embed a product sold on Amazon? How to embed a customer?

# %% [markdown]
# # NLP Output: downstream tasks
#
# ### It is something we do every day...
#
# Let's recall your English and Chinese exams, what type of tasks are you assigned?
#
# One kind of task is making selections. You are given multiple options and you are supposed to select the correct one or multiple answers. Choose A, Bingo! Or " Is Bill Gates a person or a location?" Answer: person.
#
# This kind of task is similar to <font color='blue'>classification</font> problem in ML.
#
# Another kind of task during exam is generative in nature: fill the blank with the best words, answer questions based on context, or writing some paragraph or essay based on prompts.
#
# "Elon Musk bought twitter in 2022, and he did something that terrified everyone... Even the director who sleeps in the office was fired. " Question: "What thing did Elon mask did that scared everyone?" Anwser: "He fired many people. "
#
# "Write an essay about the impact of bankrupcy of Sillicon Vally Bank".
#
# This kind of task is <font color='blue'>generative tasks</font>
# , which makes chatGPT super popular today.

# %% [markdown]
# <font color='red'>Assignment:</font> List all tasks you can find that NLP can solve now. Refer to GLUE, superGLUE, BLU, SQuAD, SWAG, CoNLL-2003, MultiNLI etc for reference. Classify them into the two types of tasks listed above. Do you find some tasks that do not fall into these two categories?

# %% [markdown]
# <font color='red'>Assignment:</font> Given one application for each downstream task.

# %% [markdown]
# <font color='red'>Question:</font> Given a word, what tasks can you perform?

# %%
Tokenizer, stemmization, word to vec.

# %% [markdown]
# <font color='red'>Question:</font> Given a sentence, what tasks can you perform?

# %% [markdown]
# Sentiment analysis, aspect sentiment analysis, NER, POS tagging, SRL, chunking, Masked Language Modeling, translation, QA.

# %% [markdown]
# <font color='red'>Question:</font> Given a sentence pair, what tasks can you perform?

# %%
Next sentence modeling, QA consistency check, sentence similarity,

# %% [markdown]
# <font color='red'>Question:</font> Given a paragraph, what tasks can you perform?

# %% [markdown]
# Text summarization, QA based on context, Natural Language Inference. Completion. Topic modeling. Aspect sentiment analysis.

# %% [markdown]
# <font color='red'>Question:</font> Given a big dictionary like wikipedia, what tasks can you perform?

# %%
Pre-training a big language model. Build knowledge graph.

# %% [markdown]
# # Building models

# %% [markdown]
# # Transformer Architecture

# %% [markdown]
# Paper: Attention is all your need https://arxiv.org/abs/1706.03762
# Youtube explanation: https://www.youtube.com/watch?v=nzqlFIcCSWQ&list=PLFXJ6jwg0qW-7UM8iUTj3qKqdhbQULP5I&index=6

# %% [markdown]
# <font color='red'>Question:</font> What is a transformer architecture? Is transformer a CNN? Is transformer a RNN?

# %% [markdown]
# <font color='red'>Question:</font>  What part of transformer is similar to the convolutional layer of CNN, and why?

# %% [markdown]
# Multi-head attention. Multi-channel input, multi-chanel output.

# %% [markdown]
# <font color='red'>Question:</font> What makes transformer so special and efficient compared to CNN and RNN is self-attention. Attention is all you need! Explain self attention. Why it is a good structure?

# %% [markdown]
# Self-Attention = kqv. It is highly paralizable, and the model can see the whole sentence at a time.

# %% [markdown]
# <font color='red'>Question:</font> What is the advantage of transformer architecture compared to RNN?

# %% [markdown]
# Can be parallelized, fast to compute.

# %% [markdown]
# <font color='red'>Question:</font> Explain residual-connect module. What is the function of res-connect module in transformer?

# %% [markdown]
# <font color='red'>Question:</font> What are the difference between the architectures of encoder and decoder?

# %% [markdown]
# <font color='red'>Assignment:</font> Write code to calculate one-head self-attention score given k, q, v.

# %% [markdown]
# # Bert Architecture
# Paper: https://arxiv.org/abs/1810.04805
# Youtube Video: https://www.youtube.com/watch?v=ULD3uIb2MHQ

# %% [markdown]
# <font color='red'>Assignment:</font> Learn the architecture of BERT following the youtube video provided at least once, and answer the following questions:

# %% [markdown]
# <font color='red'>Question:</font> Give the full name of BERT, explain each word in the full name.

# %% [markdown]
# <font color='red'>Question:</font> What is the relationship between BERT and transformer?

# %% [markdown]
# Both developed in google, BERT only uses encoder

# %% [markdown]
# <font color='red'>Question:</font> What part/ideas of BERT are from ELMO and GPT?

# %% [markdown]
# ELMO uses RNN but is bi-directional. GPT uses transformer architecuture but uni-directional. BERT combines the bi-directional and transformer architecture. But BERT uses encoder but GPT uses decoder.

# %% [markdown]
# <font color='red'>Question:</font> Explain why BERT needs positional embedding? How is positional embedding implemented (text OK, code preferred)?

# %% [markdown]
# <font color='red'>Question:</font> How is BERT trained? What is Masked Language Modeling (MLM) and Next sentence prediction (NSP)? Does it needs human labeling? What is this method of training sample construction called?

# %% [markdown]
# <font color='red'>Question:</font> What hyper-parameters do you need to adjust for fine-tuning a BERT model? What are the typical ranges?

# %% [markdown]
# Batch size: 16, 32, 64, 128
#
# Learning rate (Adam): 5e-5, 3e-5, 2e-5
#
# Number of epochs: 2,3,4

# %% [markdown]
# <font color='red'>Question:</font> What is a token? What is tokenizer? Is one token a word? What type of tokenizer does BERT adopt? How many tokens are there? Why the author of BERT used this kind of tokenizer instead of a big dictionary?

# %% [markdown]
# <font color='red'>Question:</font> Distinguish the following methods: active learning, semi-supervised learning, self-supervised learning, weak supervised learning, contrastive learning.

# %% [markdown]
# # Bert Application

# %% [markdown]
# <font color='red'>Question:</font> Explain what is transfer learning, what is fine-tuning. Why we fine-tune the model instead of training from scratch?

# %% [markdown]
# <font color='red'>Question:</font> What parameters are tuned when training a bert based model?

# %% [markdown]
# <font color='red'>Question:</font> What is model distillation? Why we need model distillation?

# %% [markdown]
# <font color='red'>Question:</font>

# %% [markdown]
# # Hands-on Project: Bert based sentiment analysis
